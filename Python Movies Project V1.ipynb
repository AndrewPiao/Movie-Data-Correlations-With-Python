# %%
# Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#Reading in data

df = pd.read_csv(r'C:\Users\andy_\Downloads\Portfolio\Movies Python Correlation\movies.csv')

# %%
#Looking at data

df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#In case we want to view all the data

#pd.set_option('display.max_rows', None)

# %%
#Seeking and removing rows with any missing data

df = df.dropna(how='any',axis=0) 

#Checking 

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
#Checking data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Changing budget, gross, runtime, and votes from float64 type to simpler int64 type and name into object

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')
df['votes'] = df['votes'].astype('int64')
#df['score'] = df['score'].astype('float64')
#df['name'] = df['name'].astype('object')

#Checking again after conversion of relevant data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
#Creating correct year column according to 'released' column rather than 'year' column

df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype('int64')

#Checking
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
#Removing incorrect year column

df = df.drop("year", axis = 'columns')

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
#Backup datafield

df2 = df
df2
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
#Sorting list by 'gross'

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score    votes             director  \
# ...

# %%
#Quick look at correlations

correlation_matrix = df.corr(numeric_only = [False])
correlation_matrix
# Out:
#                 score     votes    budget     gross   runtime  yearcorrect
# score        1.000000  0.474256  0.072001  0.222556  0.414068     0.061923
# votes        0.474256  1.000000  0.439675  0.614751  0.352303     0.203098
# budget       0.072001  0.439675  1.000000  0.740247  0.318695     0.320312
# gross        0.222556  0.614751  0.740247  1.000000  0.275796     0.268721
# runtime      0.414068  0.352303  0.318695  0.275796  1.000000     0.075294
# yearcorrect  0.061923  0.203098  0.320312  0.268721  0.075294     1.000000

# %%
#Correlation Matrix Heatmap for easier visuals

sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix Heatmap')
plt.ylabel('Movie Features')
plt.xlabel('Movie Features')
plt.show()

# %%
#Finding correlatino between budget vs gross with RegPlot  

sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color":"red"}, line_kws={"color":"purple"})

plt.title('Budget vs Gross Earnings')
plt.ylabel('Gross Earnings (Billion)')
plt.xlabel('Budget (Hundred Million)')
# Out:
# Text(0.5, 0, 'Budget (Hundred Million)')

# %%
#Finding correlatino between score vs gross with RegPlot  

sns.regplot(x="score", y="gross", data=df, scatter_kws={"color":"red"}, line_kws={"color":"purple"})

plt.title('Score vs Gross Earnings')
plt.ylabel('Gross Earnings (Billion)')
plt.xlabel('Score')
# Out:
# Text(0.5, 0, 'Score')

# %%
#Applying numerics to unique objects for easier matrix visuals

df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized

#df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#       name  rating  genre  released  score    votes  director  writer  star  \
# 0     4692       6      6      1304    8.4   927000      1795    2832   699
# 1     3929       6      1      1127    5.8    65000      1578    1158   214
# 2     3641       4      0      1359    8.7  1200000       757    1818  1157
# 3      204       4      4      1127    7.7   221000       889    1413  1474
# 4      732       6      4      1170    7.3   108000       719     351   271
# ...    ...     ...    ...       ...    ...      ...       ...     ...   ...
# 7648   415       6      0       904    6.6   140000        16    2390  1812
# 7649  3556       4      0       713    6.5   102000       852    2309   147
# 7650  1153       4      1       904    5.6    53000      1809    2827  1470
# 7651  3978       4      1       758    6.8    42000       294    2091   640
# 7652  4090       3      0       370    6.8     3700       746    1184  1839
#
# ...

# %%
#Correlation Matrix Heatmap for easier visuals

correlation_matrix = df_numerized.corr(numeric_only = [False])
correlation_matrix 
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix Heatmap')
plt.ylabel('Movie Features') 
plt.xlabel('Movie Features')
plt.show()

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# budget       genre         -0.368523
# genre        budget        -0.368523
#              gross         -0.244101
# gross        genre         -0.244101
# rating       budget        -0.203946
#                               ...
# released     released       1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 225, dtype: float64
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# ...

# %%
#Isolating highly correlated data

high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#It seems vote and budget has highest correlation to gross
